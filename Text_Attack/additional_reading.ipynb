# %% [markdown]
# # 端到端使用 TextAttack 进行攻击
# TextAttack 是一个关于自然语言处理模型（nlp）对抗攻击的 python 框架。它实现了对抗攻击、数据增强以及模型训练等功能。本材料利用其端到端的命令行接口 textattack 进行简单的 NLP 对抗攻击以及评估。
#
# 具体细节可参考[TextAttack 官方仓库](https://github.com/QData/TextAttack)以及[TextAttack 官方文档](https://textattack.readthedocs.io/en/master/)
#
# ---

# %% [markdown]
# 使用 pip 安装 textattack 库

# %%
# !pip install textattack

# %% [markdown]
# ### 1. 训练
# 首先我们可以对nlp模型进行训练。TextAttack 集成了 transformers 库与 datasets 库（均来自 huggingface），因此可以加载 datasets 库支持的数据集来训练 transformers 库支持的预训练模型。
#
# 在此，我们使用 Rotten Tomatoes Movie Review 训练集。首先使用```textattack peek-dataset```来展示数据集的信息。
#
# 下载数据集需要将HF_ENDPOINT改为国内镜像。
#
# 过程中下载 NLTK_data 很慢，很大概率最终会下载失败。在运行之后的命令时会提示没找到，然后显示“Search in ... (some path)”，这是程序期望 nltk_data 所在的位置。此时可以使用 [nltk_data 的 github 仓库](https://github.com/nltk/nltk_data) ，将其中的 packages 目录下载后，放在之前错误信息提到的位置中，重命名为 nltk_data 并解压就可以了（很大，3.6G，~~用完记得删除~~）。

# %%
# !HF_ENDPOINT=https://hf-mirror.com textattack peek-dataset --dataset-from-huggingface rotten_tomatoes
# Out:
# 2025-04-07 11:22:48.282187: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-07 11:22:48.599321: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-04-07 11:22:49.435609: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# textattack: Loading datasets dataset rotten_tomatoes, split train.
# textattack: Number of samples: 8530
# textattack: Number of words per input:
# textattack: 	total:   157755
# textattack: 	mean:    18.49
# textattack: 	std:     8.58
# textattack: 	min:     1
# textattack: 	max:     51
# textattack: Dataset lowercased: True
# textattack: First sample:
# the rock is destined to be the 21st century's new " conan " and that he's going to make a splash even greater than arnold schwarzenegger , jean-claud van damme or steven segal .
#
# textattack: Last sample:
# things really get weird , though not particularly scary : the movie is all portent and no content .
#
# textattack: Found 2 distinct outputs.
# textattack: Most common outputs:
# 	 1      (4265)
# 	 0      (4265)

# %% [markdown]
# 这个代码可以递归解压 nltk_data 目录下的所有 zip 文件并删除解压完的 zip 文件。

# %%
# 解压 nltk_data 并删除所有 zip 文件的代码
import os
import zipfile

def extract_and_remove_zips(root_dir):
    for folder, _, files in os.walk(root_dir):
        for file in files:
            if file.endswith(".zip"):
                zip_path = os.path.join(folder, file)
                extract_path = folder  # 解压到当前 ZIP 文件所在的目录
                
                try:
                    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
                        zip_ref.extractall(extract_path)
                    print(f"Extracted: {zip_path} -> {extract_path}")
                    os.remove(zip_path)
                    print(f"Deleted: {zip_path}")
                except Exception as e:
                    print(f"Error processing {zip_path}: {e}")

if __name__ == "__main__":
    root_directory = ""  # 替换为你的目标目录
    extract_and_remove_zips(root_directory)

# %% [markdown]
# 接下来我们将要训练 [`distilbert-base-uncased`](https://huggingface.co/transformers/model_doc/distilbert.html)，它是一个相对较小的模型，但也能很好的展示 `textattack` 库是如何与 `transformers` 库结合的。同样的由于网络速度原因，需要指定环境变量将HF_ENDPOINT改为国内镜像。
#
# 所以接下来将要运行命令：
# ```shell
# textattack train                      \ # 使用 textattack 训练一个模型
#     --model distilbert-base-uncased   \ # 使用 distilbert 模型, uncased 版本。模型来自 `transformers`
#     --dataset rotten_tomatoes         \ # 在 Rotten Tomatoes 数据集
#     --model-num-labels 2              \ # 训练集有 2 个标签
#     --model-max-length 64             \ # 最大输入序列长度为 64
#     --per-device-train-batch-size 128 \ # batch_size 设置为 128
#     --num-epochs 3                    \ # 训练 3 轮
# ```

# %%
# !HF_ENDPOINT=https://hf-mirror.com textattack train --model-name-or-path distilbert-base-uncased --dataset rotten_tomatoes --model-num-labels 2 --model-max-length 64 --per-device-train-batch-size 128 --num-epochs 3
# Out:
# 2025-04-07 11:24:49.912007: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-07 11:24:49.932613: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-04-07 11:24:50.286524: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# textattack: Loading transformers AutoModelForSequenceClassification: distilbert-base-uncased
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# textattack: Loading datasets dataset rotten_tomatoes, split train.
# textattack: Loading datasets dataset rotten_tomatoes, split validation.
# textattack: Writing logs to ./outputs/2025-04-07-11-24-51-083260/train_log.txt.
# textattack: Wrote original training args to ./outputs/2025-04-07-11-24-51-083260/training_args.json.
# /home/zrz/miniconda3/envs/TA/lib/python3.8/site-packages/transformers/optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# textattack: ***** Running training *****
# textattack:   Num examples = 8530
# textattack:   Num epochs = 3
# textattack:   Num clean epochs = 3
# textattack:   Instantaneous batch size per device = 128
# textattack:   Total train batch size (w. parallel, distributed & accumulation) = 128
# textattack:   Gradient accumulation steps = 1
# textattack:   Total optimization steps = 201
# textattack: ==========================================================
# textattack: Epoch 1
# textattack: Running clean epoch 1/3
# Loss 0.67815: 100%|█████████████████████████████| 67/67 [00:04<00:00, 14.69it/s]
# textattack: Train accuracy: 58.52%
# textattack: Eval accuracy: 78.61%
# textattack: Best score found. Saved model to ./outputs/2025-04-07-11-24-51-083260/best_model/
# textattack: ==========================================================
# textattack: Epoch 2
# textattack: Running clean epoch 2/3
# Loss 0.56227: 100%|█████████████████████████████| 67/67 [00:04<00:00, 14.70it/s]
# textattack: Train accuracy: 81.11%
# textattack: Eval accuracy: 83.96%
# textattack: Best score found. Saved model to ./outputs/2025-04-07-11-24-51-083260/best_model/
# textattack: ==========================================================
# textattack: Epoch 3
# textattack: Running clean epoch 3/3
# Loss 0.48541: 100%|█████████████████████████████| 67/67 [00:04<00:00, 14.69it/s]
# textattack: Train accuracy: 86.11%
# textattack: Eval accuracy: 84.71%
# textattack: Best score found. Saved model to ./outputs/2025-04-07-11-24-51-083260/best_model/
# textattack: Wrote README to ./outputs/2025-04-07-11-24-51-083260/README.md.

# %% [markdown]
# 使用 `textattack eval` 来评估刚才训练的模型，注意将 `--model` 参数改为刚才训练模型保存的文件

# %%
# !HF_ENDPOINT=https://hf-mirror.com textattack eval --num-examples 1000 --model ./outputs/2025-03-27-11-58-31-902283/best_model/ --dataset-from-huggingface rotten_tomatoes --dataset-split test
# Out:
# 2025-04-07 11:26:31.305533: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-07 11:26:31.326019: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-04-07 11:26:31.678785: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# textattack: Loading datasets dataset rotten_tomatoes, split test.
# textattack: Got 1000 predictions.
# textattack: Correct 842/1000 (84.20%)

# %% [markdown]
# 接下来使用集成的`textattack attack`对刚才的模型进行攻击，这里使用`textfooler`方法进行攻击。

# %%
# !HF_ENDPOINT=https://hf-mirror.com TFHUB_CACHE_DIR=./tmp textattack attack --recipe textfooler --num-examples 100 --model ./outputs/2025-03-27-11-58-31-902283/best_model/ --dataset-from-huggingface rotten_tomatoes --dataset-split test
# Out:
# 2025-04-07 11:28:38.707237: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-07 11:28:38.737897: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-04-07 11:28:39.351913: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# textattack: Loading datasets dataset rotten_tomatoes, split test.
# textattack: Unknown if model of class <class 'transformers.models.distilbert.modeling_distilbert.DistilBertForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Attack(
#   (search_method): GreedyWordSwapWIR(
#     (wir_method):  delete
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  WordSwapEmbedding(
#     (max_candidates):  50
#     (embedding):  WordEmbedding
#   )
#   (constraints):
#     (0): WordEmbeddingDistance(
#         (embedding):  WordEmbedding
#         (min_cos_sim):  0.5
#         (cased):  False
#         (include_unknown_words):  True
#         (compare_against_original):  True
#       )
#     (1): PartOfSpeech(
#         (tagger_type):  nltk
#         (tagset):  universal
#         (allow_verb_noun_swap):  True
#         (compare_against_original):  True
#       )
#     (2): UniversalSentenceEncoder(
#         (metric):  angular
#         (threshold):  0.840845057
#         (window_size):  15
#         (skip_text_shorter_than_window):  True
#         (compare_against_original):  False
#       )
#     (3): RepeatModification
#     (4): StopwordModification
#     (5): InputColumnModification(
#         (matching_column_labels):  ['premise', 'hypothesis']
#         (columns_to_ignore):  {'premise'}
#       )
#   (is_black_box):  True
# )
#
#   0%|                                                   | 0/100 [00:00<?, ?it/s]2025-04-07 11:28:53.639879: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-07 11:28:53.640010: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-07 11:28:53.739125: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-07 11:28:53.739238: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-07 11:28:53.739293: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-07 11:28:53.739337: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-07 11:28:53.790383: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-07 11:28:53.790472: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-07 11:28:53.790531: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-07 11:28:53.790582: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-07 11:28:53.790630: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-07 11:28:53.790673: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-07 11:28:53.795076: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-07 11:28:53.795163: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-07 11:28:53.795220: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-07 11:28:53.795271: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-07 11:28:53.795319: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-07 11:28:53.795372: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14158 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9
# 2025-04-07 11:28:53.795489: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-04-07 11:28:53.795533: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 22272 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:05:00.0, compute capability: 8.9
# 2025-04-07 11:28:56.617701: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:231] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.9
# 2025-04-07 11:28:56.617723: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:234] Used ptxas at ptxas
# 2025-04-07 11:28:56.617760: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:189] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-04-07 11:28:56.617771: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:189] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-04-07 11:28:56.617786: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:189] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-04-07 11:28:56.617800: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:189] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-04-07 11:28:56.617810: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:189] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-04-07 11:28:56.617818: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:189] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-04-07 11:28:56.617826: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:189] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-04-07 11:28:56.617837: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:189] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-04-07 11:28:56.617847: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:189] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-04-07 11:28:56.617857: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:189] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-04-07 11:28:56.617867: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:189] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-04-07 11:28:56.617879: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:189] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-04-07 11:28:56.617890: W tensorflow/compiler/mlir/tools/kernel_gen/transforms/gpu_kernel_to_blob_pass.cc:189] Failed to compile generated PTX with ptxas. Falling back to compilation by driver.
# 2025-04-07 11:28:56.829825: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
#   1%|▍                                          | 1/100 [00:03<05:47,  3.51s/it]--------------------------------------------- Result 1 ---------------------------------------------
# Positive (96%) --> Negative (73%)
#
# lovingly photographed in the manner of a golden book sprung to life , stuart little 2 manages sweetness largely without stickiness .
#
# clumsily photographed in the manner of a golden book sprung to life , stuart little 2 manage sweetness largely without stickiness .
#
#
# [Succeeded / Failed / Skipped / Total] 1 / 0 / 0 / 1:   2%| | 2/100 [00:03<02:58--------------------------------------------- Result 2 ---------------------------------------------
# Positive (98%) --> Negative (91%)
#
# consistently clever and suspenseful .
#
# consistently malin and enigmatic .
#
#
# [Succeeded / Failed / Skipped / Total] 2 / 0 / 0 / 2:   2%| | 2/100 [00:03<02:58--------------------------------------------- Result 3 ---------------------------------------------
# Negative (86%) --> [38:5:240m[SKIPPED]
#
# it's like a " big chill " reunion of the baader-meinhof gang , only these guys are more harmless pranksters than political activists .
#
#
# [Succeeded / Failed / Skipped / Total] 2 / 0 / 1 / 3:   3%| | 3/100 [00:03<01:58--------------------------------------------- Result 4 ---------------------------------------------
# Positive (98%) --> Negative (54%)
#
# the story gives ample opportunity for large-scale action and suspense , which director shekhar kapur supplies with tremendous skill .
#
# the story gives ample opportunity for large-scale action and suspense , which director shekhar kapur supplies with stupendous skilful .
#
#
# [Succeeded / Failed / Skipped / Total] 3 / 0 / 1 / 4:   4%| | 4/100 [00:03<01:29--------------------------------------------- Result 5 ---------------------------------------------
# Negative (78%) --> [38:5:240m[SKIPPED]
#
# red dragon " never cuts corners .
#
#
# [Succeeded / Failed / Skipped / Total] 3 / 0 / 2 / 5:   6%| | 6/100 [00:03<00:59--------------------------------------------- Result 6 ---------------------------------------------
# Positive (61%) --> Negative (54%)
#
# fresnadillo has something serious to say about the ways in which extravagant chance can distort our perspective and throw us off the path of good sense .
#
# fresnadillo haya something serious to say about the ways in which extravagant chance can distort our perspective and throw us off the path of good sense .
#
#
# [Succeeded / Failed / Skipped / Total] 4 / 0 / 2 / 6:   6%| | 6/100 [00:03<00:59--------------------------------------------- Result 7 ---------------------------------------------
# Positive (97%) --> Negative (69%)
#
# throws in enough clever and unexpected twists to make the formula feel fresh .
#
# throws in enough clever and unwanted tendrils to make the formula feel fresh .
#
#
# [Succeeded / Failed / Skipped / Total] 5 / 0 / 2 / 7:   7%| | 7/100 [00:04<00:54--------------------------------------------- Result 8 ---------------------------------------------
# Negative (79%) --> [38:5:240m[SKIPPED]
#
# weighty and ponderous but every bit as filling as the treat of the title .
#
#
# [Succeeded / Failed / Skipped / Total] 5 / 0 / 3 / 8:   8%| | 8/100 [00:04<00:46--------------------------------------------- Result 9 ---------------------------------------------
# Positive (97%) --> Negative (65%)
#
# a real audience-pleaser that will strike a chord with anyone who's ever waited in a doctor's office , emergency room , hospital bed or insurance company office .
#
# a hardheaded audience-pleaser that will slugged a chords with anyone who's ever waited in a doctor's office , emergency room , hospital bed or insurance company office .
#
#
# [Succeeded / Failed / Skipped / Total] 6 / 0 / 3 / 9:  10%| | 10/100 [00:04<00:3--------------------------------------------- Result 10 ---------------------------------------------
# Positive (98%) --> Negative (94%)
#
# generates an enormous feeling of empathy for its characters .
#
# generates an dreaded premonition of empathy for its characters .
#
#
# [Succeeded / Failed / Skipped / Total] 7 / 0 / 3 / 10:  10%| | 10/100 [00:04<00:--------------------------------------------- Result 11 ---------------------------------------------
# Positive (98%) --> Negative (61%)
#
# exposing the ways we fool ourselves is one hour photo's real strength .
#
# exposing the ways we fool ourselves is one hour photo's real strenght .
#
#
# [Succeeded / Failed / Skipped / Total] 8 / 0 / 3 / 11:  11%| | 11/100 [00:04<00:--------------------------------------------- Result 12 ---------------------------------------------
# Negative (60%) --> [38:5:240m[SKIPPED]
#
# it's up to you to decide whether to admire these people's dedication to their cause or be repelled by their dogmatism , manipulativeness and narrow , fearful view of american life .
#
#
# [Succeeded / Failed / Skipped / Total] 8 / 0 / 4 / 12:  12%| | 12/100 [00:04<00:--------------------------------------------- Result 13 ---------------------------------------------
# Negative (62%) --> [38:5:240m[SKIPPED]
#
# mostly , [goldbacher] just lets her complicated characters be unruly , confusing and , through it all , human .
#
#
# [Succeeded / Failed / Skipped / Total] 8 / 0 / 5 / 13:  13%|▏| 13/100 [00:04<00:--------------------------------------------- Result 14 ---------------------------------------------
# Positive (85%) --> Negative (56%)
#
# . . . quite good at providing some good old fashioned spooks .
#
# . . . quite bestest at providing some good old fashioned spooks .
#
#
# [Succeeded / Failed / Skipped / Total] 9 / 0 / 5 / 14:  14%|▏| 14/100 [00:04<00:--------------------------------------------- Result 15 ---------------------------------------------
# Negative (93%) --> [38:5:240m[SKIPPED]
#
# at its worst , the movie is pretty diverting ; the pity is that it rarely achieves its best .
#
#
# [Succeeded / Failed / Skipped / Total] 9 / 0 / 6 / 15:  16%|▏| 16/100 [00:04<00:--------------------------------------------- Result 16 ---------------------------------------------
# Positive (99%) --> Negative (52%)
#
# scherfig's light-hearted profile of emotional desperation is achingly honest and delightfully cheeky .
#
# scherfig's light-hearted characterize of psychiatric desperation is achingly franc and blithely cheeky .
#
#
# [Succeeded / Failed / Skipped / Total] 10 / 0 / 6 / 16:  16%|▏| 16/100 [00:04<00--------------------------------------------- Result 17 ---------------------------------------------
# Positive (98%) --> Negative (54%)
#
# a journey spanning nearly three decades of bittersweet camaraderie and history , in which we feel that we truly know what makes holly and marina tick , and our hearts go out to them as both continue to negotiate their imperfect , love-hate relationship .
#
# a trekking expectancy nearly three decades of bittersweet camaraderie and history , in which we feel that we truly know what makes holly and marina tick , and our cardiology go out to them as both being to negotiate their imperfect , love-hate relationship .
#
#
# [Succeeded / Failed / Skipped / Total] 11 / 0 / 6 / 17:  17%|▏| 17/100 [00:04<00--------------------------------------------- Result 18 ---------------------------------------------
# Positive (93%) --> Negative (68%)
#
# the wonderfully lush morvern callar is pure punk existentialism , and ms . ramsay and her co-writer , liana dognini , have dramatized the alan warner novel , which itself felt like an answer to irvine welsh's book trainspotting .
#
# the appallingly languid morvern callar is pure punk existentialism , and ms . ramsay and her co-writer , liana dognini , have dramatized the alan warner novel , which itself felt like an answer to irvine welsh's book trainspotting .
#
#
# [Succeeded / Failed / Skipped / Total] 12 / 0 / 6 / 18:  18%|▏| 18/100 [00:04<00--------------------------------------------- Result 19 ---------------------------------------------
# Positive (57%) --> Negative (69%)
#
# as it turns out , you can go home again .
#
# as it pivot out , you can go accomodation again .
#
#
# [Succeeded / Failed / Skipped / Total] 13 / 0 / 6 / 19:  19%|▏| 19/100 [00:04<00--------------------------------------------- Result 20 ---------------------------------------------
# Positive (91%) --> Negative (85%)
#
# you've already seen city by the sea under a variety of titles , but it's worth yet another visit .
#
# you've already seen city by the sea under a variety of titles , but it's chastisement yet another visit .
#
#
# [Succeeded / Failed / Skipped / Total] 14 / 0 / 6 / 20:  20%|▏| 20/100 [00:04<00--------------------------------------------- Result 21 ---------------------------------------------
# Positive (97%) --> Negative (50%)
#
# this kind of hands-on storytelling is ultimately what makes shanghai ghetto move beyond a good , dry , reliable textbook and what allows it to rank with its worthy predecessors .
#
# this kind of hands-on myth is ultimately what makes shanghai ghetto move beyond a opportune , dry , reliable textbook and what allows it to rank with its reputable predecessors .
#
#
# [Succeeded / Failed / Skipped / Total] 15 / 0 / 6 / 21:  22%|▏| 22/100 [00:04<00--------------------------------------------- Result 22 ---------------------------------------------
# Positive (75%) --> Negative (53%)
#
# making such a tragedy the backdrop to a love story risks trivializing it , though chouraqui no doubt intended the film to affirm love's power to help people endure almost unimaginable horror .
#
# making such a tragedy the backdrop to a love story risque trivializing it , though chouraqui no doubt intended the film to affirm love's power to help people endure almost unimaginable horror .
#
#
# [Succeeded / Failed / Skipped / Total] 16 / 0 / 6 / 22:  22%|▏| 22/100 [00:04<00--------------------------------------------- Result 23 ---------------------------------------------
# Negative (51%) --> [38:5:240m[SKIPPED]
#
# grown-up quibbles are beside the point here . the little girls understand , and mccracken knows that's all that matters .
#
#
# [Succeeded / Failed / Skipped / Total] 16 / 0 / 7 / 23:  23%|▏| 23/100 [00:04<00--------------------------------------------- Result 24 ---------------------------------------------
# Positive (99%) --> Negative (94%)
#
# a powerful , chilling , and affecting study of one man's dying fall .
#
# a pompous , refrigeration , and affecting study of one man's dying decreased .
#
#
# [Succeeded / Failed / Skipped / Total] 17 / 0 / 7 / 24:  24%|▏| 24/100 [00:04<00--------------------------------------------- Result 25 ---------------------------------------------
# Positive (64%) --> Negative (65%)
#
# this is a fascinating film because there is no clear-cut hero and no all-out villain .
#
# this is a interesting film because there is no clear-cut hero and no all-out villain .
#
#
# [Succeeded / Failed / Skipped / Total] 18 / 0 / 7 / 25:  25%|▎| 25/100 [00:04<00--------------------------------------------- Result 26 ---------------------------------------------
# Positive (79%) --> Negative (88%)
#
# a dreadful day in irish history is given passionate , if somewhat flawed , treatment .
#
# a dreadful day in irish history is given voracious , if somewhat flawed , treatment .
#
#
# [Succeeded / Failed / Skipped / Total] 19 / 0 / 7 / 26:  26%|▎| 26/100 [00:04<00--------------------------------------------- Result 27 ---------------------------------------------
# Positive (89%) --> Negative (91%)
#
# . . . a good film that must have baffled the folks in the marketing department .
#
# . . . a ok film that must have baffled the folks in the marketing department .
#
#
# [Succeeded / Failed / Skipped / Total] 20 / 0 / 7 / 27:  28%|▎| 28/100 [00:05<00--------------------------------------------- Result 28 ---------------------------------------------
# Positive (98%) --> Negative (72%)
#
# . . . is funny in the way that makes you ache with sadness ( the way chekhov is funny ) , profound without ever being self-important , warm without ever succumbing to sentimentality .
#
# . . . is jest in the methodology that makes you ache with sadness ( the way chekhov is funny ) , shum without ever being self-important , warmer without ever succumbing to sentimentality .
#
#
# [Succeeded / Failed / Skipped / Total] 21 / 0 / 7 / 28:  28%|▎| 28/100 [00:05<00--------------------------------------------- Result 29 ---------------------------------------------
# Negative (96%) --> [38:5:240m[SKIPPED]
#
# devotees of star trek ii : the wrath of khan will feel a nagging sense of deja vu , and the grandeur of the best next generation episodes is lacking .
#
#
# [Succeeded / Failed / Skipped / Total] 21 / 0 / 8 / 29:  29%|▎| 29/100 [00:05<00--------------------------------------------- Result 30 ---------------------------------------------
# Positive (99%) --> [FAILED]
#
# a soul-stirring documentary about the israeli/palestinian conflict as revealed through the eyes of some children who remain curious about each other against all odds .
#
#
# [Succeeded / Failed / Skipped / Total] 21 / 1 / 8 / 30:  30%|▎| 30/100 [00:05<00--------------------------------------------- Result 31 ---------------------------------------------
# Positive (80%) --> Negative (82%)
#
# what's so striking about jolie's performance is that she never lets her character become a caricature -- not even with that radioactive hair .
#
# what's so staggering about jolie's performance is that she never lets her character become a caricature -- not even with that radioactive hair .
#
#
# [Succeeded / Failed / Skipped / Total] 22 / 1 / 8 / 31:  31%|▎| 31/100 [00:05<00--------------------------------------------- Result 32 ---------------------------------------------
# Negative (65%) --> [38:5:240m[SKIPPED]
#
# the main story . . . is compelling enough , but it's difficult to shrug off the annoyance of that chatty fish .
#
#
# [Succeeded / Failed / Skipped / Total] 22 / 1 / 9 / 32:  32%|▎| 32/100 [00:05<00--------------------------------------------- Result 33 ---------------------------------------------
# Positive (95%) --> Negative (91%)
#
# the performances are immaculate , with roussillon providing comic relief .
#
# the performances are faultless , with roussillon providing comic relief .
#
#
# [Succeeded / Failed / Skipped / Total] 23 / 1 / 9 / 33:  34%|▎| 34/100 [00:05<00--------------------------------------------- Result 34 ---------------------------------------------
# Positive (97%) --> Negative (52%)
#
# kinnear . . . gives his best screen performance with an oddly winning portrayal of one of life's ultimate losers .
#
# kinnear . . . stipulates his best screen performance with an oddly wins similarity of one of life's ultimate losers .
#
#
# [Succeeded / Failed / Skipped / Total] 24 / 1 / 9 / 34:  34%|▎| 34/100 [00:05<00--------------------------------------------- Result 35 ---------------------------------------------
# Positive (59%) --> Negative (65%)
#
# hugh grant , who has a good line in charm , has never been more charming than in about a boy .
#
# hugh grant , who has a bonne line in charm , has never been more charming than in about a boy .
#
#
# [Succeeded / Failed / Skipped / Total] 25 / 1 / 9 / 35:  35%|▎| 35/100 [00:05<00--------------------------------------------- Result 36 ---------------------------------------------
# Positive (81%) --> Negative (55%)
#
# there's a lot of tooth in roger dodger . but what's nice is that there's a casual intelligence that permeates the script .
#
# there's a lot of tooth in roger dodger . but what's gentil is that there's a casual intelligence that permeates the script .
#
#
# [Succeeded / Failed / Skipped / Total] 26 / 1 / 9 / 36:  36%|▎| 36/100 [00:05<00--------------------------------------------- Result 37 ---------------------------------------------
# Negative (76%) --> [38:5:240m[SKIPPED]
#
# reminiscent of alfred hitchcock's thrillers , most of the scary parts in 'signs' occur while waiting for things to happen .
#
#
# [Succeeded / Failed / Skipped / Total] 26 / 1 / 10 / 37:  37%|▎| 37/100 [00:05<0--------------------------------------------- Result 38 ---------------------------------------------
# Positive (98%) --> Negative (52%)
#
# one of the best looking and stylish animated movies in quite a while . . .
#
# one of the strictest looking and shiny animated movies in quite a while . . .
#
#
# [Succeeded / Failed / Skipped / Total] 27 / 1 / 10 / 38:  38%|▍| 38/100 [00:05<0--------------------------------------------- Result 39 ---------------------------------------------
# Positive (98%) --> Negative (50%)
#
# its use of the thriller form to examine the labyrinthine ways in which people's lives cross and change , buffeted by events seemingly out of their control , is intriguing , provocative stuff .
#
# its use of the thriller form to examine the labyrinthine ways in which people's lives cross and change , buffeted by events seemingly out of their control , is baffling , provocative stuff .
#
#
# [Succeeded / Failed / Skipped / Total] 28 / 1 / 10 / 39:  40%|▍| 40/100 [00:05<0--------------------------------------------- Result 40 ---------------------------------------------
# Positive (94%) --> Negative (56%)
#
# denver should not get the first and last look at one of the most triumphant performances of vanessa redgrave's career . it deserves to be seen everywhere .
#
# denver envisaged not get the first and last look at one of the most triumphant performances of vanessa redgrave's career . it deserves to be seen everywhere .
#
#
# [Succeeded / Failed / Skipped / Total] 29 / 1 / 10 / 40:  40%|▍| 40/100 [00:05<0--------------------------------------------- Result 41 ---------------------------------------------
# Positive (58%) --> Negative (61%)
#
# you needn't be steeped in '50s sociology , pop culture or movie lore to appreciate the emotional depth of haynes' work . though haynes' style apes films from the period . . . its message is not rooted in that decade .
#
# you needn't be steeped in '50s sociology , pop culture or movie lore to appreciate the emotional depth of haynes' work . albeit haynes' style apes films from the period . . . its message is not rooted in that decade .
#
#
# [Succeeded / Failed / Skipped / Total] 30 / 1 / 10 / 41:  41%|▍| 41/100 [00:05<0--------------------------------------------- Result 42 ---------------------------------------------
# Positive (93%) --> Negative (68%)
#
# waiting for godard can be fruitful : 'in praise of love' is the director's epitaph for himself .
#
# waiting for godard can be propitious : 'in praise of love' is the director's epitaph for himself .
#
#
# [Succeeded / Failed / Skipped / Total] 31 / 1 / 10 / 42:  42%|▍| 42/100 [00:05<0--------------------------------------------- Result 43 ---------------------------------------------
# Positive (93%) --> Negative (94%)
#
# a gangster movie with the capacity to surprise .
#
# a gangster movie with the capacity to flabbergasted .
#
#
# [Succeeded / Failed / Skipped / Total] 32 / 1 / 10 / 43:  43%|▍| 43/100 [00:05<0--------------------------------------------- Result 44 ---------------------------------------------
# Positive (68%) --> Negative (84%)
#
# the film has a laundry list of minor shortcomings , but the numerous scenes of gory mayhem are worth the price of admission . . . if " gory mayhem " is your idea of a good time .
#
# the film has a laundry list of minor shortcomings , but the numerous scenes of gory mayhem are priceless the price of admission . . . if " gory mayhem " is your idea of a good time .
#
#
# [Succeeded / Failed / Skipped / Total] 33 / 1 / 10 / 44:  44%|▍| 44/100 [00:06<0--------------------------------------------- Result 45 ---------------------------------------------
# Negative (54%) --> [38:5:240m[SKIPPED]
#
# if not a home run , then at least a solid base hit .
#
#
# [Succeeded / Failed / Skipped / Total] 33 / 1 / 11 / 45:  46%|▍| 46/100 [00:06<0--------------------------------------------- Result 46 ---------------------------------------------
# Positive (89%) --> Negative (77%)
#
# goldmember is funny enough to justify the embarrassment of bringing a barf bag to the moviehouse .
#
# goldmember is comical enough to justify the embarrassment of bringing a barf bag to the moviehouse .
#
#
# [Succeeded / Failed / Skipped / Total] 34 / 1 / 11 / 46:  46%|▍| 46/100 [00:06<0--------------------------------------------- Result 47 ---------------------------------------------
# Positive (73%) --> Negative (93%)
#
# . . . a fairly disposable yet still entertaining b picture .
#
# . . . a fairly disposable yet still droll b picture .
#
#
# [Succeeded / Failed / Skipped / Total] 35 / 1 / 11 / 47:  47%|▍| 47/100 [00:06<0--------------------------------------------- Result 48 ---------------------------------------------
# Positive (99%) --> Negative (50%)
#
# it may not be particularly innovative , but the film's crisp , unaffected style and air of gentle longing make it unexpectedly rewarding .
#
# it may not be particularly unpublished , but the film's crisp , unaffected style and air of sugary vacuuming doing it unexpectedly bounties .
#
#
# [Succeeded / Failed / Skipped / Total] 36 / 1 / 11 / 48:  48%|▍| 48/100 [00:06<0--------------------------------------------- Result 49 ---------------------------------------------
# Positive (89%) --> Negative (92%)
#
# the film truly does rescue [the funk brothers] from motown's shadows . it's about time .
#
# the film awfully does rescue [the funk brothers] from motown's shadows . it's about time .
#
#
# [Succeeded / Failed / Skipped / Total] 37 / 1 / 11 / 49:  49%|▍| 49/100 [00:06<0--------------------------------------------- Result 50 ---------------------------------------------
# Positive (98%) --> Negative (60%)
#
# drawing on an irresistible , languid romanticism , byler reveals the ways in which a sultry evening or a beer-fueled afternoon in the sun can inspire even the most retiring heart to venture forth .
#
# drawing on an stupendous , languid romanticism , byler divulged the means in which a sultry evening or a beer-fueled afternoon in the sun can inspire even the most retiring heart to venture forth .
#
#
# [Succeeded / Failed / Skipped / Total] 38 / 1 / 11 / 50:  50%|▌| 50/100 [00:06<0--------------------------------------------- Result 51 ---------------------------------------------
# Negative (93%) --> [38:5:240m[SKIPPED]
#
# works because we're never sure if ohlinger's on the level or merely a dying , delusional man trying to get into the history books before he croaks .
#
#
# [Succeeded / Failed / Skipped / Total] 38 / 1 / 12 / 51:  52%|▌| 52/100 [00:06<0--------------------------------------------- Result 52 ---------------------------------------------
# Positive (67%) --> Negative (59%)
#
# [scherfig] has made a movie that will leave you wondering about the characters' lives after the clever credits roll .
#
# [scherfig] has made a cine that will leave you wondering about the characters' lives after the cleverer credits roll .
#
#
# [Succeeded / Failed / Skipped / Total] 39 / 1 / 12 / 52:  52%|▌| 52/100 [00:06<0--------------------------------------------- Result 53 ---------------------------------------------
# Positive (98%) --> Negative (54%)
#
# a heady , biting , be-bop ride through nighttime manhattan , a loquacious videologue of the modern male and the lengths to which he'll go to weave a protective cocoon around his own ego .
#
# a disordered , gnawing , be-bop ride through nighttime manhattan , a loquacious videologue of the upgraded male and the lengths to which he'll go to weave a protective cocoon around his own ego .
#
#
# [Succeeded / Failed / Skipped / Total] 40 / 1 / 12 / 53:  53%|▌| 53/100 [00:06<0--------------------------------------------- Result 54 ---------------------------------------------
# Positive (97%) --> Negative (76%)
#
# skin of man gets a few cheap shocks from its kids-in-peril theatrics , but it also taps into the primal fears of young people trying to cope with the mysterious and brutal nature of adults .
#
# skin of man gets a few cheap shocks from its kids-in-peril theatrics , but it also faucets into the rudimentary fears of young people trying to cope with the mysterious and brutal nature of adults .
#
#
# [Succeeded / Failed / Skipped / Total] 41 / 1 / 12 / 54:  54%|▌| 54/100 [00:06<0--------------------------------------------- Result 55 ---------------------------------------------
# Positive (94%) --> Negative (70%)
#
# the piano teacher is not an easy film . it forces you to watch people doing unpleasant things to each other and themselves , and it maintains a cool distance from its material that is deliberately unsettling .
#
# the piano teacher is not an easy film . it serviceman you to watch people doing unpleasant things to each other and themselves , and it maintains a icebox distance from its material that is deliberately uneasy .
#
#
# [Succeeded / Failed / Skipped / Total] 42 / 1 / 12 / 55:  55%|▌| 55/100 [00:06<0--------------------------------------------- Result 56 ---------------------------------------------
# Positive (96%) --> Negative (92%)
#
# as refreshing as a drink from a woodland stream .
#
# as retrofit as a drink from a woodland stream .
#
#
# [Succeeded / Failed / Skipped / Total] 43 / 1 / 12 / 56:  56%|▌| 56/100 [00:06<0--------------------------------------------- Result 57 ---------------------------------------------
# Positive (63%) --> Negative (94%)
#
# williams absolutely nails sy's queasy infatuation and overall strangeness .
#
# williams absolutely nails sy's queasy infatuation and overall ennui .
#
#
# [Succeeded / Failed / Skipped / Total] 44 / 1 / 12 / 57:  58%|▌| 58/100 [00:06<0--------------------------------------------- Result 58 ---------------------------------------------
# Positive (65%) --> Negative (54%)
#
# can i admit xxx is as deep as a petri dish and as well-characterized as a telephone book but still say it was a guilty pleasure ?
#
# can i admit xxx is as deep as a petri dish and as well-characterized as a telephone book but still say it was a guilty pleasures ?
#
#
# [Succeeded / Failed / Skipped / Total] 45 / 1 / 12 / 58:  58%|▌| 58/100 [00:06<0--------------------------------------------- Result 59 ---------------------------------------------
# Positive (84%) --> Negative (52%)
#
# while it's nothing we haven't seen before from murphy , i spy is still fun and enjoyable and so aggressively silly that it's more than a worthwhile effort .
#
# while it's nothing we haven't seen before from murphy , i spy is still fun and gentil and so aggressively silly that it's more than a worthwhile effort .
#
#
# [Succeeded / Failed / Skipped / Total] 46 / 1 / 12 / 59:  59%|▌| 59/100 [00:06<0--------------------------------------------- Result 60 ---------------------------------------------
# Positive (55%) --> Negative (77%)
#
# by the time it ends in a rush of sequins , flashbulbs , blaring brass and back-stabbing babes , it has said plenty about how show business has infiltrated every corner of society -- and not always for the better .
#
# by the time it ends in a rush of sequins , flashbulbs , blaring brass and back-stabbing babes , it has said lots about how show business has infiltrated every corner of society -- and not always for the better .
#
#
# [Succeeded / Failed / Skipped / Total] 47 / 1 / 12 / 60:  60%|▌| 60/100 [00:06<0--------------------------------------------- Result 61 ---------------------------------------------
# Positive (98%) --> Negative (85%)
#
# an intimate contemplation of two marvelously messy lives .
#
# an squeamish contemplation of two marvelously messy lives .
#
#
# [Succeeded / Failed / Skipped / Total] 48 / 1 / 12 / 61:  61%|▌| 61/100 [00:06<0--------------------------------------------- Result 62 ---------------------------------------------
# Positive (60%) --> Negative (55%)
#
# rarely has skin looked as beautiful , desirable , even delectable , as it does in trouble every day .
#
# rarely has skin looked as nice , desirable , even delectable , as it does in trouble every day .
#
#
# [Succeeded / Failed / Skipped / Total] 49 / 1 / 12 / 62:  62%|▌| 62/100 [00:06<0--------------------------------------------- Result 63 ---------------------------------------------
# Positive (97%) --> Negative (62%)
#
# this is one of those rare docs that paints a grand picture of an era and makes the journey feel like a party .
#
# this is one of those rare physician that paint a gargantuan picture of an periods and doing the journey feel like a section .
#
#
# [Succeeded / Failed / Skipped / Total] 50 / 1 / 12 / 63:  64%|▋| 64/100 [00:07<0--------------------------------------------- Result 64 ---------------------------------------------
# Positive (98%) --> Negative (95%)
#
# poignant if familiar story of a young person suspended between two cultures .
#
# disheartening if familiar story of a young person suspended between two cultures .
#
#
# [Succeeded / Failed / Skipped / Total] 51 / 1 / 12 / 64:  64%|▋| 64/100 [00:07<0--------------------------------------------- Result 65 ---------------------------------------------
# Positive (94%) --> Negative (94%)
#
# a metaphor for a modern-day urban china searching for its identity .
#
# a cliché for a modern-day urban china searching for its identifications .
#
#
# [Succeeded / Failed / Skipped / Total] 52 / 1 / 12 / 65:  65%|▋| 65/100 [00:07<0--------------------------------------------- Result 66 ---------------------------------------------
# Positive (98%) --> Negative (83%)
#
# for all its brooding quality , ash wednesday is suspenseful and ultimately unpredictable , with a sterling ensemble cast .
#
# for all its brooding quality , ash wednesday is cliffhanger and ultimately unpredictable , with a stirling ensemble cast .
#
#
# [Succeeded / Failed / Skipped / Total] 53 / 1 / 12 / 66:  66%|▋| 66/100 [00:07<0--------------------------------------------- Result 67 ---------------------------------------------
# Positive (89%) --> Negative (70%)
#
# an odd drama set in the world of lingerie models and bar dancers in the midwest that held my interest precisely because it didn't try to .
#
# an odd cataclysmic set in the worid of lingerie models and bar dancers in the midwest that held my interest precisely because it didn't try to .
#
#
# [Succeeded / Failed / Skipped / Total] 54 / 1 / 12 / 67:  67%|▋| 67/100 [00:07<0--------------------------------------------- Result 68 ---------------------------------------------
# Positive (78%) --> Negative (59%)
#
# the film feels uncomfortably real , its language and locations bearing the unmistakable stamp of authority .
#
# the film feels uncomfortably real , its language and locations bearing the discernible stamp of authority .
#
#
# [Succeeded / Failed / Skipped / Total] 55 / 1 / 12 / 68:  68%|▋| 68/100 [00:07<0--------------------------------------------- Result 69 ---------------------------------------------
# Positive (98%) --> Negative (87%)
#
# despite its faults , gangs excels in spectacle and pacing .
#
# despite its faults , gangs overwhelms in spectacle and pacing .
#
#
# [Succeeded / Failed / Skipped / Total] 56 / 1 / 12 / 69:  70%|▋| 70/100 [00:07<0--------------------------------------------- Result 70 ---------------------------------------------
# Positive (80%) --> Negative (72%)
#
# entertaining despite its one-joke premise with the thesis that women from venus and men from mars can indeed get together .
#
# amusement despite its one-joke premise with the thesis that women from venus and men from mars can indeed get together .
#
#
# [Succeeded / Failed / Skipped / Total] 57 / 1 / 12 / 70:  70%|▋| 70/100 [00:07<0--------------------------------------------- Result 71 ---------------------------------------------
# Positive (97%) --> Negative (91%)
#
# a tightly directed , highly professional film that's old-fashioned in all the best possible ways .
#
# a tightly directed , excessively professional film that's old-fashioned in all the best possible ways .
#
#
# [Succeeded / Failed / Skipped / Total] 58 / 1 / 12 / 71:  71%|▋| 71/100 [00:07<0--------------------------------------------- Result 72 ---------------------------------------------
# Positive (97%) --> Negative (53%)
#
# it's dark but has wonderfully funny moments ; you care about the characters ; and the action and special effects are first-rate .
#
# it's dismal but is unspeakably comedy dated ; you considerate about the characters ; and the action and special effects are first-rate .
#
#
# [Succeeded / Failed / Skipped / Total] 59 / 1 / 12 / 72:  72%|▋| 72/100 [00:07<0--------------------------------------------- Result 73 ---------------------------------------------
# Positive (86%) --> Negative (55%)
#
# in visual fertility treasure planet rivals the top japanese animations of recent vintage .
#
# in visual fertility treasure planet rivals the supremo japanese animations of recent vintage .
#
#
# [Succeeded / Failed / Skipped / Total] 60 / 1 / 12 / 73:  73%|▋| 73/100 [00:07<0--------------------------------------------- Result 74 ---------------------------------------------
# Positive (99%) --> Negative (94%)
#
# enormously enjoyable , high-adrenaline documentary .
#
# enormously droll , high-adrenaline paperwork .
#
#
# [Succeeded / Failed / Skipped / Total] 61 / 1 / 12 / 74:  74%|▋| 74/100 [00:07<0--------------------------------------------- Result 75 ---------------------------------------------
# Positive (98%) --> Negative (94%)
#
# buy is an accomplished actress , and this is a big , juicy role .
#
# buy is an ended actress , and this is a big , crusty role .
#
#
# [Succeeded / Failed / Skipped / Total] 62 / 1 / 12 / 75:  76%|▊| 76/100 [00:07<0--------------------------------------------- Result 76 ---------------------------------------------
# Positive (98%) --> Negative (70%)
#
# it works its magic with such exuberance and passion that the film's length becomes a part of its fun .
#
# it functioned its magic with such naiveté and passion that the film's length becomes a part of its banter .
#
#
# [Succeeded / Failed / Skipped / Total] 63 / 1 / 12 / 76:  76%|▊| 76/100 [00:07<0--------------------------------------------- Result 77 ---------------------------------------------
# Positive (99%) --> Negative (64%)
#
# beautifully crafted and brutally honest , promises offers an unexpected window into the complexities of the middle east struggle and into the humanity of its people .
#
# appallingly prepped and brutally veritable , promises proposing an unexpected window into the complexities of the middle east tussle and into the humans of its people .
#
#
# [Succeeded / Failed / Skipped / Total] 64 / 1 / 12 / 77:  77%|▊| 77/100 [00:08<0--------------------------------------------- Result 78 ---------------------------------------------
# Positive (98%) --> Negative (81%)
#
# an old-fashioned but emotionally stirring adventure tale of the kind they rarely make anymore .
#
# an old-fashioned but emotionally tumult adventure tale of the kind they rarely make anymore .
#
#
# [Succeeded / Failed / Skipped / Total] 65 / 1 / 12 / 78:  78%|▊| 78/100 [00:08<0--------------------------------------------- Result 79 ---------------------------------------------
# Positive (98%) --> Negative (93%)
#
# charlotte sometimes is a gem . it's always enthralling .
#
# charlotte sometimes is a bling . it's always hallucinatory .
#
#
# [Succeeded / Failed / Skipped / Total] 66 / 1 / 12 / 79:  79%|▊| 79/100 [00:08<0--------------------------------------------- Result 80 ---------------------------------------------
# Positive (93%) --> Negative (50%)
#
# in my opinion , analyze that is not as funny or entertaining as analyze this , but it is a respectable sequel .
#
# in my kwun , analyze that is not as funny or amusement as analysed this , but it is a proper sequel .
#
#
# [Succeeded / Failed / Skipped / Total] 67 / 1 / 12 / 80:  80%|▊| 80/100 [00:08<0--------------------------------------------- Result 81 ---------------------------------------------
# Positive (98%) --> Negative (95%)
#
# a remarkable film by bernard rose .
#
# a whopping film by bernard rose .
#
#
# [Succeeded / Failed / Skipped / Total] 68 / 1 / 12 / 81:  82%|▊| 82/100 [00:08<0--------------------------------------------- Result 82 ---------------------------------------------
# Positive (61%) --> Negative (52%)
#
# zhuangzhuang creates delicate balance of style , text , and subtext that's so simple and precise that anything discordant would topple the balance , but against all odds , nothing does .
#
# zhuangzhuang produces delicate balance of style , text , and subtext that's so simple and precise that anything discordant would topple the balance , but against all odds , nothing does .
#
#
# [Succeeded / Failed / Skipped / Total] 69 / 1 / 12 / 82:  82%|▊| 82/100 [00:08<0--------------------------------------------- Result 83 ---------------------------------------------
# Positive (78%) --> Negative (54%)
#
# a much more successful translation than its most famous previous film adaptation , writer-director anthony friedman's similarly updated 1970 british production .
#
# a much more succeeded translation than its most famous previous film adaptation , writer-director anthony friedman's similarly updated 1970 british production .
#
#
# [Succeeded / Failed / Skipped / Total] 70 / 1 / 12 / 83:  83%|▊| 83/100 [00:08<0--------------------------------------------- Result 84 ---------------------------------------------
# Positive (99%) --> Negative (63%)
#
# an original and highly cerebral examination of the psychopathic mind
#
# an rudimentary and highly cerebral examination of the psychopathic mind
#
#
# [Succeeded / Failed / Skipped / Total] 71 / 1 / 12 / 84:  84%|▊| 84/100 [00:08<0--------------------------------------------- Result 85 ---------------------------------------------
# Positive (94%) --> Negative (92%)
#
# michel piccoli's moving performance is this films reason for being .
#
# michel piccoli's displaced performance is this films reason for being .
#
#
# [Succeeded / Failed / Skipped / Total] 72 / 1 / 12 / 85:  85%|▊| 85/100 [00:08<0--------------------------------------------- Result 86 ---------------------------------------------
# Positive (99%) --> Negative (82%)
#
# a captivating and intimate study about dying and loving . . .
#
# a hallucinatory and cosy scrutinized about dying and loving . . .
#
#
# [Succeeded / Failed / Skipped / Total] 73 / 1 / 12 / 86:  86%|▊| 86/100 [00:08<0--------------------------------------------- Result 87 ---------------------------------------------
# Positive (97%) --> Negative (65%)
#
# this is an elegantly balanced movie -- every member of the ensemble has something fascinating to do -- that doesn't reveal even a hint of artifice .
#
# this is an prettily balancing movie -- every member of the ensemble has something fascinating to do -- that doesn't reveal even a hint of artifice .
#
#
# [Succeeded / Failed / Skipped / Total] 74 / 1 / 12 / 87:  88%|▉| 88/100 [00:08<0--------------------------------------------- Result 88 ---------------------------------------------
# Positive (98%) --> Negative (52%)
#
# [grant] goes beyond his usual fluttering and stammering and captures the soul of a man in pain who gradually comes to recognize it and deal with it .
#
# [subsidy] goes beyond his usual fluttering and stammering and incarcerate the wits of a man in pain who gradually arrives to recognize it and deal with it .
#
#
# [Succeeded / Failed / Skipped / Total] 75 / 1 / 12 / 88:  88%|▉| 88/100 [00:08<0--------------------------------------------- Result 89 ---------------------------------------------
# Positive (97%) --> Negative (57%)
#
# a high-spirited buddy movie about the reunion of berlin anarchists who face arrest 15 years after their crime .
#
# a high-spirited buddy photographed about the pooling of germania anarchist who facial halts 15 annum after their contravention .
#
#
# [Succeeded / Failed / Skipped / Total] 76 / 1 / 12 / 89:  89%|▉| 89/100 [00:08<0--------------------------------------------- Result 90 ---------------------------------------------
# Negative (74%) --> [38:5:240m[SKIPPED]
#
# about the best thing you could say about narc is that it's a rock-solid little genre picture . whether you like it or not is basically a matter of taste .
#
#
# [Succeeded / Failed / Skipped / Total] 76 / 1 / 13 / 90:  90%|▉| 90/100 [00:08<0--------------------------------------------- Result 91 ---------------------------------------------
# Positive (98%) --> Negative (87%)
#
# an involving , inspirational drama that sometimes falls prey to its sob-story trappings .
#
# an involving , incite cataclysmic that sometimes falls prey to its sob-story trappings .
#
#
# [Succeeded / Failed / Skipped / Total] 77 / 1 / 13 / 91:  91%|▉| 91/100 [00:08<0--------------------------------------------- Result 92 ---------------------------------------------
# Positive (96%) --> Negative (62%)
#
# some of the most inventive silliness you are likely to witness in a movie theatre for some time .
#
# some of the most contrivance silliness you are likely to witness in a movie theatre for some time .
#
#
# [Succeeded / Failed / Skipped / Total] 78 / 1 / 13 / 92:  92%|▉| 92/100 [00:08<0--------------------------------------------- Result 93 ---------------------------------------------
# Positive (99%) --> Negative (65%)
#
# canadian filmmaker gary burns' inventive and mordantly humorous take on the soullessness of work in the city .
#
# canadian filmmaker gary burns' inventor and mordantly mockery having on the soullessness of work in the shing .
#
#
# [Succeeded / Failed / Skipped / Total] 79 / 1 / 13 / 93:  94%|▉| 94/100 [00:09<0--------------------------------------------- Result 94 ---------------------------------------------
# Positive (97%) --> Negative (62%)
#
# a rollicking ride , with jaw-dropping action sequences , striking villains , a gorgeous color palette , astounding technology , stirring music and a boffo last hour that leads up to a strangely sinister happy ending .
#
# a rollicking wrinkle , with jaw-dropping action sequences , striking villains , a leggy color palette , astounding technology , stirring music and a boffo last hour that leads up to a strangely sinister happiest ending .
#
#
# [Succeeded / Failed / Skipped / Total] 80 / 1 / 13 / 94:  94%|▉| 94/100 [00:09<0--------------------------------------------- Result 95 ---------------------------------------------
# Positive (99%) --> Negative (72%)
#
# everyone's insecure in lovely and amazing , a poignant and wryly amusing film about mothers , daughters and their relationships .
#
# everyone's insecure in lovely and whopping , a disquieting and wryly amusing film about mothers , daughters and their relationships .
#
#
# [Succeeded / Failed / Skipped / Total] 81 / 1 / 13 / 95:  95%|▉| 95/100 [00:09<0--------------------------------------------- Result 96 ---------------------------------------------
# Negative (64%) --> [38:5:240m[SKIPPED]
#
# the closest thing to the experience of space travel
#
#
# [Succeeded / Failed / Skipped / Total] 81 / 1 / 14 / 96:  96%|▉| 96/100 [00:09<0--------------------------------------------- Result 97 ---------------------------------------------
# Positive (96%) --> Negative (97%)
#
# full of surprises .
#
# full of stupor .
#
#
# [Succeeded / Failed / Skipped / Total] 82 / 1 / 14 / 97:  97%|▉| 97/100 [00:09<0--------------------------------------------- Result 98 ---------------------------------------------
# Positive (88%) --> Negative (62%)
#
# connoisseurs of chinese film will be pleased to discover that tian's meticulous talent has not withered during his enforced hiatus .
#
# connoisseurs of chinese film will be flattered to discover that tian's meticulous talent acres not withered during his enforced hiatus .
#
#
# [Succeeded / Failed / Skipped / Total] 83 / 1 / 14 / 98:  98%|▉| 98/100 [00:09<0--------------------------------------------- Result 99 ---------------------------------------------
# Positive (93%) --> Negative (50%)
#
# if you can push on through the slow spots , you'll be rewarded with some fine acting .
#
# if you can push on through the slow spots , you'll be recompense with some sumptuous acting .
#
#
# [Succeeded / Failed / Skipped / Total] 84 / 1 / 14 / 99: 100%|█| 100/100 [00:09<--------------------------------------------- Result 100 ---------------------------------------------
# Positive (69%) --> Negative (62%)
#
# an unusually dry-eyed , even analytical approach to material that is generally played for maximum moisture .
#
# an unusually dry-eyed , even analytical approaching to material that is generally played for maximum moisture .
#
#
# [Succeeded / Failed / Skipped / Total] 85 / 1 / 14 / 100: 100%|█| 100/100 [00:09
#
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 85     |
# | Number of failed attacks:     | 1      |
# | Number of skipped attacks:    | 14     |
# | Original accuracy:            | 86.0%  |
# | Accuracy under attack:        | 1.0%   |
# | Attack success rate:          | 98.84% |
# | Average perturbed word %:     | 13.04% |
# | Average num. words per input: | 18.45  |
# | Avg num queries:              | 70.4   |
# +-------------------------------+--------+

# %% [markdown]
# 输出中包含非常多的信息：包含每个样本攻击前与攻击后的对比，以及模型预测的变化。最后有一张 Attack Results 表来展示攻击的结果。Attack success rate 代表攻击成功率（即模型错误判断的概率），Original accuracy 代表模型在干净样本上的正确率

# %% [markdown]
# textattack 还集成了许多其他攻击方式，感兴趣的同学可以参考[官方文档](https://textattack.readthedocs.io/en/master/)进行进一步的探索
